# %%
from google.colab import drive # Import a library named google.colab
drive.mount('/content/drive', force_remount=True) # mount the content to the directory `/content/drive`

# %cd /content/drive/MyDrive/Tensorflow_Practice
# !mkdir HW13     # I HAVE MADE IT.
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Tensorflow_Practice

# %% [markdown]
# # Article:https://towardsdatascience.com/why-not-mse-as-a-loss-function-for-logistic-regression-589816b5e03c

# %%
import numpy as np  

y_predicted = np.array([1, 1, 0, 0, 1])
y_true = np.array([0.30, 0.7, 1, 0, 0.5])

# %%
def mae(y_true, y_predicted):
  total_error = 0
  for yt, yp in zip(y_true, y_predicted):
    total_error += abs(yt - yp)
  print("Total error:", total_error)
  mae_score = total_error / len(y_true)
  print("MAE:", mae_score)
  return mae_score

np.mean(np.abs(y_predicted - y_true)) # mean is the average
# Out:
# 0.5

# %%
mae(y_true, y_predicted)
# Out:
# Total error: 2.5
# MAE: 0.5
# 0.5

# %%
np.log([2.7])  # the base is euler number: 2.71828
# Out:
# array([0.99325177])

# %%
epsilon = 1e-15
y_predicted_new = [max(i, epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_predicted_new = [min(i, 1-epsilon) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean(y_true*np.log(y_predicted_new) + (1-y_true)*np.log(1-y_predicted_new))
# Out:
# 17.2696280766844

# %%
def LogLoss_or_Cross_Entropy(y_true,  y_predicted):
  epsilon = 1e-15
  y_predicted_new = [max(i, epsilon) for i in y_predicted]
  y_predicted_new = [min(i, 1-epsilon) for i in y_predicted_new]
  y_predicted_new = np.array(y_predicted_new)
  return -np.mean(y_true*np.log(y_predicted_new) + (1-y_true)*np.log(1-y_predicted_new))

# %%
def mse(y_true, y_predicted):
  return np.mean(np.abs(y_predicted - y_true)**2) # mean is the average 
  # return np.square(np.square(y_predicted - y_true))

# %%
mse(y_true, y_predicted)
# Out:
# 0.366

# %% [markdown]
# # How Cross-Entropy looks like

# %%
import pandas as pd 
import math 
import matplotlib.pyplot as plt
import warnings 
# %matplotlib inline 
warnings.filterwarnings("ignore")
p = np.arange(0, 1, 0.01)
plt.plot(p, -1 * np.log(p))
# plt.show()
plt.plot(p, -1 * (np.log(1-p)), 'orange')
plt.show()
